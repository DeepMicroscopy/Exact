# %% [markdown]
# ## Import Datasets Notebook
# -process for importing WSI or DCM datasets (images & labels) into Exact

# %%
# %reload_ext autoreload
# %autoreload 2
# %matplotlib inline

# %%
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
import matplotlib.patches as patches
import pandas as pd

from exact_sync.v1.api.annotations_api import AnnotationsApi
from exact_sync.v1.api.images_api import ImagesApi
from exact_sync.v1.api.image_sets_api import ImageSetsApi
from exact_sync.v1.api.annotation_types_api import AnnotationTypesApi

from exact_sync.v1.models import ImageSet, Team, Product, AnnotationType, Image, Annotation, AnnotationMediaFile
from exact_sync.v1.rest import ApiException
from exact_sync.v1.configuration import Configuration
from exact_sync.v1.api_client import ApiClient

from pathlib import Path

# %% [markdown]
# ### Set-up Exact Server Connection

# %%
configuration = Configuration()
configuration.username = 'bnapora'
configuration.password = 'bnapora'
configuration.host = "http://127.0.0.1:8000"

client = ApiClient(configuration)

image_sets_api = ImageSetsApi(client)
annotations_api = AnnotationsApi(client)
annotation_types_api = AnnotationTypesApi(client)
images_api = ImagesApi(client)

# %%
# image_sets_api.list_image_sets()

# %%
image_sets = image_sets_api.list_image_sets(name__contains='CCMCT')
image_sets
# Out:
# {'count': 1,
#  'next': None,
#  'previous': None,
#  'results': [{'creator': 1,
#               'description': '',
#               'id': 4,
#               'images': [55,
#                          56,
#                          57,
#                          58,
#                          59,
#                          60,
#                          61,
#                          62,
#                          63,
#                          64,
#                          65,
#                          66,
#                          67,
#                          68,
#                          69,
#                          70,
#                          71,
#                          72,
#                          73,
#                          74,
#                          75,
#                          76,
#                          77,
#                          78,
#                          79,
#                          80,
#                          81,
#                          82,
#                          83,
#                          84,
#                          85,
#                          86],
#               'location': None,
#               'main_annotation_type': None,
#               'name': 'MITOSIS_WSI_CCMCT',
#               'path': 'exact_1_4',
#               'product_set': [3],
#               'set_tags': [],
#               'team': 1}]}

# %%
list_imageset_images = []
image_sets.count
for image_set in image_sets.results:
    imageset_images = images_api.list_images(image_set=image_set.id)
    for image in imageset_images.results:
        list_imageset_images.append([image.id, image.filename])
#         list_imageset_images[image.filename] = image.id
        
print(list_imageset_images)
# Out:
# [[55, '2f17d43b3f9e7dacf24c.svs'], [56, '20c0753af38303691b27.svs'], [57, '285f74bb6be025a676b6.svs'], [58, 'c3eb4b8382b470dd63a9.svs'], [59, 'c91a842257ed2add5134.svs'], [60, 'f26e9fcef24609b988be.svs'], [61, '066c94c4c161224077a9.svs'], [62, '0e56fd11a762be0983f0.svs'], [63, '1018715d369dd0df2fc0.svs'], [64, '2e611073cff18d503cea.svs'], [65, '2efb541724b5c017c503.svs'], [66, '2f2591b840e83a4b4358.svs'], [67, '34eb28ce68c1106b2bac.svs'], [68, '39ecf7f94ed96824405d.svs'], [69, '3f2e034c75840cb901e6.svs'], [70, '552c51bfb88fd3e65ffe.svs'], [71, '70ed18cd5f806cf396f0.svs'], [72, '8bebdd1f04140ed89426.svs'], [73, '8c9f9618fcaca747b7c3.svs'], [74, '91a8e57ea1f9cb0aeb63.svs'], [75, '9374efe6ac06388cc877.svs'], [76, '96274538c93980aad8d6.svs'], [77, 'a0c8b612fe0655eab3ce.svs'], [78, 'ac1168b2c893d2acad38.svs'], [79, 'add0a9bbc53d1d9bac4c.svs'], [80, 'be10fa37ad6e88e1f406.svs'], [81, 'c86cd41f96331adf3856.svs'], [82, 'ce949341ba99845813ac.svs'], [83, 'dd4246ab756f6479c841.svs'], [84, 'dd6dd0d54b81ebc59c77.svs'], [85, 'f3741e764d39ccc4d114.svs'], [86, 'fff27b79894fe0157b08.svs']]

# %% [markdown]
# ### Upload Multiple Images from Directory

# %%
path_images = Path('/host_Data/DataSets/MITOS_WSI_CCMCT/WSI')
id_imageset = 4
type_wsi = {'.svs', '.scn'}
# [x for x in path_images.iterdir()]

# %%
# for path_image in path_images.iterdir():
#     if Path(path_image).suffix in type_wsi:
#         print (path_image)
#         images_api.create_image(file_path=path_image, image_set=id_imageset)

# %% [markdown]
# ### Upload Annotations for Images

# %% [markdown]
# #### Import from SlideRunner (sqlite db)

# %%
pathDB = Path('/host_Data/DataSets/MITOS_WSI_CCMCT/databases')
dbname = 'MITOS_WSI_CCMCT_ODAEL.sqlite'

# %%
import sqlite3
from SlideRunner.dataAccess.database import Database
from tqdm import tqdm
import uuid

database = Database()
print(str(pathDB/dbname))
database.open(str(pathDB/dbname))
# Out:
# /host_Data/DataSets/MITOS_WSI_CCMCT/databases/MITOS_WSI_CCMCT_ODAEL.sqlite

# %%
# Create Class dictionary for Data Source
query_classes = 'SELECT uid, name from Classes'
classes_source = {}
for uid_class, name_class in database.execute(query_classes).fetchall():
    classes_source[uid_class] = name_class
print(classes_source)
# Out:
# {1: 'granulocyte', 2: 'mitotic figure', 3: 'tumor cell', 4: 'other/ambiguous cells', 5: 'binucleated cell', 6: 'multinukleated cell', 7: 'Mitotic figure lookalike', 11: 'background'}

# %%
# Create Class dictionary for Data Target (Exact)
annotation_types = annotation_types_api.list_annotation_types(product=3)
classes_exact = {}
for result in annotation_types.results:
    classes_exact[result.name] = result.id
print(classes_exact)
# Out:
# {'granulocyte': 13, 'mitotic figure': 14, 'tumor cell': 15, 'other/ambiguous cells': 16, 'binucleated cell': 17, 'multinukleated cell': 18, 'Mitotic figure lookalike': 19, 'background': 20}

# %%
#Map Class Dictionaries
classes_map = {}
for class_source in classes_source:
    classes_map[class_source] = classes_exact[classes_source[class_source]]
print(classes_map)
# Out:
# {1: 13, 2: 14, 3: 15, 4: 16, 5: 17, 6: 18, 7: 19, 11: 20}

# %%
radius = 25

# %%
results_annotations = []
for exact_image_id, filename in list_imageset_images[1:]:
    query_slides = 'SELECT uid, filename from Slides where filename = "' + filename + '"'
    for slide_id, filename in database.execute(query_slides).fetchall():
        database.loadIntoMemory(slide_id)
        for id, annotation in database.annotations.items():
            vector = {"x1": int(annotation.x1-radius), "y1": int(annotation.y1-radius), "x2": int(annotation.x1+radius), "y2": int(annotation.y1+radius)}
            label_name = classes_source[annotation.agreedClass]
            label_id = annotation.agreedClass
            results_annotations.append([exact_image_id, vector, label_id, label_name, slide_id])
# Out:
#    exact_image_id                                             vector  \
# 0              56   {'x1': 59727, 'y1': 439, 'x2': 59777, 'y2': 489}
# 1              56  {'x1': 42473, 'y1': 7024, 'x2': 42523, 'y2': 7...
# 2              56  {'x1': 43366, 'y1': 6888, 'x2': 43416, 'y2': 6...
# 3              56  {'x1': 41866, 'y1': 7808, 'x2': 41916, 'y2': 7...
# 4              56  {'x1': 44239, 'y1': 7317, 'x2': 44289, 'y2': 7...
#
#    label_id      label_name  sliderunner_image_id
# 0         2  mitotic figure                    21
# 1         3      tumor cell                    21
# 2         3      tumor cell                    21
# 3         2  mitotic figure                    21
# 4         3      tumor cell                    21

# %%
pd_results_annotations = pd.DataFrame(results_annotations, columns=['exact_image_id', 'vector', 'label_id', 'label_name', 'sliderunner_image_id'])
pd_results_annotations.head()

# %%
len(pd_results_annotations)
# Out:
# 254184

# %%
# pd_results_annotations_tmp = pd_results_annotations.iloc[0:3].copy()
# pd_results_annotations_tmp.head()

# %%
# help(annotations_api.create_annotation)

# %%
threads = []
for image_id, vector, label in zip(pd_results_annotations['exact_image_id'], pd_results_annotations['vector'], pd_results_annotations['label_id']):
# for image_id, vector, label in zip(pd_results_annotations_tmp['exact_image_id'], pd_results_annotations_tmp['vector'], pd_results_annotations_tmp['label_id']):
    vector=vector
    unique_identifier = str(uuid.uuid4())
    exact_annotation_type = int(classes_map[label])
    image_id = int(image_id)
    annotation = Annotation(annotation_type=exact_annotation_type, image=image_id, vector=vector, unique_identifier=unique_identifier)
    thread = annotations_api.create_annotation(body=annotation)
    threads.append(thread)

# %%
annotation_results = annotations_api.list_annotations(image=55).results
print('Count of Annotations=', len(annotation_results))
# annotation_results
# Out:
# Count of Annotations= 50
# [{'annotation_type': 13,
#   'annotationversion_set': [],
#   'blurred': 'False',
#   'concealed': 'False',
#   'deleted': False,
#   'description': '',
#   'id': 404643,
#   'image': 55,
#   'last_edit_time': datetime.datetime(2021, 8, 17, 1, 43, 48, 919255),
#   'last_editor': 1,
#   'meta_data': None,
#   'time': datetime.datetime(2021, 8, 17, 1, 43, 48, 919204),
#   'unique_identifier': 'e93d5d19-36cb-4ea5-874e-cb9ed5628ed1',
#   'uploaded_media_files': [],
#   'user': 1,
#   'vector': {'x1': 21084, 'x2': 21134, 'y1': 10267, 'y2': 10317},
#   'verified_by_user': 'False'},
#  {'annotation_type': 13,
#   'annotationversion_set': [],
#   'blurred': 'False',
#   'concealed': 'False',
#   'deleted': False,
#   'description': '',
#   'id': 404644,
#   'image': 55,
#   'last_edit_time': datetime.datetime(2021, 8, 17, 1, 43, 49, 57036),
#   'last_editor': 1,
#   'meta_data': None,
#   'time': datetime.datetime(2021, 8, 17, 1, 43, 49, 56979),
#   'unique_identifier': 'f8ac135a-89bb-4590-93e6-67923464cc4c',
#   'uploaded_media_files': [],
#   'user': 1,
#   'vector': {'x1': 21610, 'x2': 21660, 'y1': 11018, 'y2': 11068},
#   'verified_by_user': 'False'},
#  {'annotation_type': 13,
#   'annotationversion_set': [],
#   'blurred': 'False',
#   'concealed': 'False',
#   'deleted': False,
#   'description': '',
#   'id': 404645,
#   'image': 55,
#   'last_edit_time': datetime.datetime(2021, 8, 17, 1, 43, 49, 230121),
#   'last_editor': 1,
#   'meta_data': None,
#   'time': datetime.datetime(2021, 8, 17, 1, 43, 49, 230070),
#   'unique_identifier': 'bad79ca8-d1b8-4323-82ed-692ba9eac8fb',
#   'uploaded_media_files': [],
#   'user': 1,
#   'vector': {'x1': 21656, 'x2': 21706, 'y1': 11064, 'y2': 11114},
#   'verified_by_user': 'False'},
#  {'annotation_type': 13,
#   'annotationversion_set': [],
#   'blurred': 'False',
#   'concealed': 'False',
#   'deleted': False,
#   'description': '',
#   'id': 404646,
#   'image': 55,
#   'last_edit_time': datetime.datetime(2021, 8, 17, 1, 43, 49, 365129),
#   'last_editor': 1,
#   'meta_data': None,
#   'time': datetime.datetime(2021, 8, 17, 1, 43, 49, 365079),
#   'unique_identifier': '2b460784-722f-4522-9692-6692a2fb38a0',
#   'uploaded_media_files': [],
#   'user': 1,
#   'vector': {'x1': 21681, 'x2': 21731, 'y1': 11098, 'y2': 11148},
#   'verified_by_user': 'False'},
#  {'annotation_type': 13,
#   'annotationversion_set': [],
#   'blurred': 'False',
#   'concealed': 'False',
#   'deleted': False,
#   'description': '',
#   'id': 404647,
#   'image': 55,
#   'last_edit_time': datetime.datetime(2021, 8, 17, 1, 43, 49, 499829),
#   'last_editor': 1,
#   'meta_data': None,
#   'time': datetime.datetime(2021, 8, 17, 1, 43, 49, 499761),
#   'unique_identifier': 'e2fd0e6f-95ea-49d5-bead-615194c4864e',
#   'uploaded_media_files': [],
#   'user': 1,
#   'vector': {'x1': 21803, 'x2': 21853, 'y1': 10958, 'y2': 11008},
#   'verified_by_user': 'False'},
#  {'annotation_type': 13,
#   'annotationversion_set': [],
#   'blurred': 'False',
#   'concealed': 'False',
#   'deleted': False,
#   'description': '',
#   'id': 404648,
#   'image': 55,
#   'last_edit_time': datetime.datetime(2021, 8, 17, 1, 43, 49, 683376),
#   'last_editor': 1,
#   'meta_data': None,
#   'time': datetime.datetime(2021, 8, 17, 1, 43, 49, 683325),
#   'unique_identifier': 'e44c6e1b-aac4-458c-8167-3fbe87538dc0',
#   'uploaded_media_files': [],
#   'user': 1,
#   'vector': {'x1': 21807, 'x2': 21857, 'y1': 10902, 'y2': 10952},
#   'verified_by_user': 'False'},
#  {'annotation_type': 13,
#   'annotationversion_set': [],
#   'blurred': 'False',
#   'concealed': 'False',
#   'deleted': False,
#   'description': '',
#   'id': 404649,
#   'image': 55,
#   'last_edit_time': datetime.datetime(2021, 8, 17, 1, 43, 49, 816299),
#   'last_editor': 1,
#   'meta_data': None,
#   'time': datetime.datetime(2021, 8, 17, 1, 43, 49, 816248),
#   'unique_identifier': '07c914c7-7c46-44f7-a25b-250d579d8b63',
#   'uploaded_media_files': [],
#   'user': 1,
#   'vector': {'x1': 21859, 'x2': 21909, 'y1': 11049, 'y2': 11099},
#   'verified_by_user': 'False'},
#  {'annotation_type': 13,
#   'annotationversion_set': [],
#   'blurred': 'False',
#   'concealed': 'False',
#   'deleted': False,
#   'description': '',
#   'id': 404650,
#   'image': 55,
#   'last_edit_time': datetime.datetime(2021, 8, 17, 1, 43, 49, 948132),
#   'last_editor': 1,
#   'meta_data': None,
#   'time': datetime.datetime(2021, 8, 17, 1, 43, 49, 948083),
#   'unique_identifier': 'd0327091-c157-4feb-9032-fca47dc9d644',
#   'uploaded_media_files': [],
#   'user': 1,
#   'vector': {'x1': 20830, 'x2': 20880, 'y1': 11255, 'y2': 11305},
#   'verified_by_user': 'False'},
#  {'annotation_type': 13,
#   'annotationversion_set': [],
#   'blurred': 'False',
#   'concealed': 'False',
#   'deleted': False,
#   'description': '',
#   'id': 404651,
#   'image': 55,
#   'last_edit_time': datetime.datetime(2021, 8, 17, 1, 43, 50, 125498),
#   'last_editor': 1,
#   'meta_data': None,
#   'time': datetime.datetime(2021, 8, 17, 1, 43, 50, 125431),
#   'unique_identifier': 'b9a05eb2-5ca0-4627-9edd-ac95446e7f67',
#   'uploaded_media_files': [],
#   'user': 1,
#   'vector': {'x1': 20897, 'x2': 20947, 'y1': 10992, 'y2': 11042},
#   'verified_by_user': 'False'},
#  {'annotation_type': 13,
#   'annotationversion_set': [],
#   'blurred': 'False',
#   'concealed': 'False',
#   'deleted': False,
#   'description': '',
#   'id': 404652,
#   'image': 55,
#   'last_edit_time': datetime.datetime(2021, 8, 17, 1, 43, 50, 271574),
#   'last_editor': 1,
#   'meta_data': None,
#   'time': datetime.datetime(2021, 8, 17, 1, 43, 50, 271522),
#   'unique_identifier': 'c8b01603-8a92-45a9-b1ef-a211759832b4',
#   'uploaded_media_files': [],
#   'user': 1,
#   'vector': {'x1': 21900, 'x2': 21950, 'y1': 11828, 'y2': 11878},
#   'verified_by_user': 'False'},
#  {'annotation_type': 13,
#   'annotationversion_set': [],
#   'blurred': 'False',
#   'concealed': 'False',
#   'deleted': False,
#   'description': '',
#   'id': 404653,
#   'image': 55,
#   'last_edit_time': datetime.datetime(2021, 8, 17, 1, 43, 50, 420804),
#   'last_editor': 1,
#   'meta_data': None,
#   'time': datetime.datetime(2021, 8, 17, 1, 43, 50, 420746),
#   'unique_identifier': '4b178a70-5cd4-4e98-abc5-c79e8da41119',
#   'uploaded_media_files': [],
#   'user': 1,
#   'vector': {'x1': 21223, 'x2': 21273, 'y1': 11670, 'y2': 11720},
#   'verified_by_user': 'False'},
#  {'annotation_type': 13,
#   'annotationversion_set': [],
#   'blurred': 'False',
#   'concealed': 'False',
#   'deleted': False,
#   'description': '',
#   'id': 404654,
#   'image': 55,
#   'last_edit_time': datetime.datetime(2021, 8, 17, 1, 43, 50, 590937),
#   'last_editor': 1,
#   'meta_data': None,
#   'time': datetime.datetime(2021, 8, 17, 1, 43, 50, 590888),
#   'unique_identifier': '90675e1e-13f1-43e5-9476-1c3314ac1893',
#   'uploaded_media_files': [],
#   'user': 1,
#   'vector': {'x1': 21273, 'x2': 21323, 'y1': 11685, 'y2': 11735},
#   'verified_by_user': 'False'},
#  {'annotation_type': 13,
#   'annotationversion_set': [],
#   'blurred': 'False',
#   'concealed': 'False',
#   'deleted': False,
#   'description': '',
#   'id': 404655,
#   'image': 55,
#   'last_edit_time': datetime.datetime(2021, 8, 17, 1, 43, 50, 724548),
#   'last_editor': 1,
#   'meta_data': None,
#   'time': datetime.datetime(2021, 8, 17, 1, 43, 50, 724499),
#   'unique_identifier': 'c781f7da-b506-4f39-9559-d7cb3cf35906',
#   'uploaded_media_files': [],
#   'user': 1,
#   'vector': {'x1': 21614, 'x2': 21664, 'y1': 12405, 'y2': 12455},
#   'verified_by_user': 'False'},
#  {'annotation_type': 13,
#   'annotationversion_set': [],
#   'blurred': 'False',
#   'concealed': 'False',
#   'deleted': False,
#   'description': '',
#   'id': 404656,
#   'image': 55,
#   'last_edit_time': datetime.datetime(2021, 8, 17, 1, 43, 50, 860293),
#   'last_editor': 1,
#   'meta_data': None,
#   'time': datetime.datetime(2021, 8, 17, 1, 43, 50, 860236),
#   'unique_identifier': 'fc3dbc42-d026-4c9b-a97b-c5c0a897e979',
#   'uploaded_media_files': [],
#   'user': 1,
#   'vector': {'x1': 21767, 'x2': 21817, 'y1': 12496, 'y2': 12546},
#   'verified_by_user': 'False'},
#  {'annotation_type': 13,
#   'annotationversion_set': [],
#   'blurred': 'False',
#   'concealed': 'False',
#   'deleted': False,
#   'description': '',
#   'id': 404657,
#   'image': 55,
#   'last_edit_time': datetime.datetime(2021, 8, 17, 1, 43, 51, 56246),
#   'last_editor': 1,
#   'meta_data': None,
#   'time': datetime.datetime(2021, 8, 17, 1, 43, 51, 56197),
#   'unique_identifier': 'ff6427c8-2fe3-44e2-bc1c-d87bdf55fb3f',
#   'uploaded_media_files': [],
#   'user': 1,
#   'vector': {'x1': 21784, 'x2': 21834, 'y1': 12525, 'y2': 12575},
#   'verified_by_user': 'False'},
#  {'annotation_type': 13,
#   'annotationversion_set': [],
#   'blurred': 'False',
#   'concealed': 'False',
#   'deleted': False,
#   'description': '',
#   'id': 404658,
#   'image': 55,
#   'last_edit_time': datetime.datetime(2021, 8, 17, 1, 43, 51, 192225),
#   'last_editor': 1,
#   'meta_data': None,
#   'time': datetime.datetime(2021, 8, 17, 1, 43, 51, 192173),
#   'unique_identifier': '472f0589-b519-488a-b3b4-9e37c0fd432f',
#   'uploaded_media_files': [],
#   'user': 1,
#   'vector': {'x1': 21894, 'x2': 21944, 'y1': 12532, 'y2': 12582},
#   'verified_by_user': 'False'},
#  {'annotation_type': 13,
#   'annotationversion_set': [],
#   'blurred': 'False',
#   'concealed': 'False',
#   'deleted': False,
#   'description': '',
#   'id': 404659,
#   'image': 55,
#   'last_edit_time': datetime.datetime(2021, 8, 17, 1, 43, 51, 329544),
#   'last_editor': 1,
#   'meta_data': None,
#   'time': datetime.datetime(2021, 8, 17, 1, 43, 51, 329490),
#   'unique_identifier': 'ee160ee8-7131-4ed4-a05d-fd0518377166',
#   'uploaded_media_files': [],
#   'user': 1,
#   'vector': {'x1': 21905, 'x2': 21955, 'y1': 12479, 'y2': 12529},
#   'verified_by_user': 'False'},
#  {'annotation_type': 13,
#   'annotationversion_set': [],
#   'blurred': 'False',
#   'concealed': 'False',
#   'deleted': False,
#   'description': '',
#   'id': 404660,
#   'image': 55,
#   'last_edit_time': datetime.datetime(2021, 8, 17, 1, 43, 51, 529378),
#   'last_editor': 1,
#   'meta_data': None,
#   'time': datetime.datetime(2021, 8, 17, 1, 43, 51, 529320),
#   'unique_identifier': '36e676c6-0c70-41c8-bf9a-8b410b95a43e',
#   'uploaded_media_files': [],
#   'user': 1,
#   'vector': {'x1': 21944, 'x2': 21994, 'y1': 12281, 'y2': 12331},
#   'verified_by_user': 'False'},
#  {'annotation_type': 13,
#   'annotationversion_set': [],
#   'blurred': 'False',
#   'concealed': 'False',
#   'deleted': False,
#   'description': '',
#   'id': 404661,
#   'image': 55,
#   'last_edit_time': datetime.datetime(2021, 8, 17, 1, 43, 51, 659708),
#   'last_editor': 1,
#   'meta_data': None,
#   'time': datetime.datetime(2021, 8, 17, 1, 43, 51, 659657),
#   'unique_identifier': '62782c36-4d56-43a7-963a-bfacfc3beeb8',
#   'uploaded_media_files': [],
#   'user': 1,
#   'vector': {'x1': 21951, 'x2': 22001, 'y1': 12239, 'y2': 12289},
#   'verified_by_user': 'False'},
#  {'annotation_type': 13,
#   'annotationversion_set': [],
#   'blurred': 'False',
#   'concealed': 'False',
#   'deleted': False,
#   'description': '',
#   'id': 404662,
#   'image': 55,
#   'last_edit_time': datetime.datetime(2021, 8, 17, 1, 43, 51, 792017),
#   'last_editor': 1,
#   'meta_data': None,
#   'time': datetime.datetime(2021, 8, 17, 1, 43, 51, 791959),
#   'unique_identifier': 'd2b50b4a-d4e7-413a-92d1-4094fea98623',
#   'uploaded_media_files': [],
#   'user': 1,
#   'vector': {'x1': 21133, 'x2': 21183, 'y1': 12493, 'y2': 12543},
#   'verified_by_user': 'False'},
#  {'annotation_type': 13,
#   'annotationversion_set': [],
#   'blurred': 'False',
#   'concealed': 'False',
#   'deleted': False,
#   'description': '',
#   'id': 404663,
#   'image': 55,
#   'last_edit_time': datetime.datetime(2021, 8, 17, 1, 43, 51, 970908),
#   'last_editor': 1,
#   'meta_data': None,
#   'time': datetime.datetime(2021, 8, 17, 1, 43, 51, 970858),
#   'unique_identifier': '09161fb4-998a-43f5-a279-b1f3665ac662',
#   'uploaded_media_files': [],
#   'user': 1,
#   'vector': {'x1': 21348, 'x2': 21398, 'y1': 12784, 'y2': 12834},
#   'verified_by_user': 'False'},
#  {'annotation_type': 13,
#   'annotationversion_set': [],
#   'blurred': 'False',
#   'concealed': 'False',
#   'deleted': False,
#   'description': '',
#   'id': 404664,
#   'image': 55,
#   'last_edit_time': datetime.datetime(2021, 8, 17, 1, 43, 52, 105900),
#   'last_editor': 1,
#   'meta_data': None,
#   'time': datetime.datetime(2021, 8, 17, 1, 43, 52, 105810),
#   'unique_identifier': '7cc79d2d-ae8e-4466-b91f-fe253888bdfb',
#   'uploaded_media_files': [],
#   'user': 1,
#   'vector': {'x1': 21377, 'x2': 21427, 'y1': 12437, 'y2': 12487},
#   'verified_by_user': 'False'},
#  {'annotation_type': 13,
#   'annotationversion_set': [],
#   'blurred': 'False',
#   'concealed': 'False',
#   'deleted': False,
#   'description': '',
#   'id': 404665,
#   'image': 55,
#   'last_edit_time': datetime.datetime(2021, 8, 17, 1, 43, 52, 237027),
#   'last_editor': 1,
#   'meta_data': None,
#   'time': datetime.datetime(2021, 8, 17, 1, 43, 52, 236973),
#   'unique_identifier': 'dd83475b-46e0-44d7-bca4-b3c52c41f799',
#   'uploaded_media_files': [],
#   'user': 1,
#   'vector': {'x1': 20682, 'x2': 20732, 'y1': 12724, 'y2': 12774},
#   'verified_by_user': 'False'},
#  {'annotation_type': 16,
#   'annotationversion_set': [],
#   'blurred': 'False',
#   'concealed': 'False',
#   'deleted': False,
#   'description': '',
#   'id': 404666,
#   'image': 55,
#   'last_edit_time': datetime.datetime(2021, 8, 17, 1, 43, 52, 420725),
#   'last_editor': 1,
#   'meta_data': None,
#   'time': datetime.datetime(2021, 8, 17, 1, 43, 52, 420675),
#   'unique_identifier': 'b04182ae-fd15-4406-ae19-3cd36c20f1b4',
#   'uploaded_media_files': [],
#   'user': 1,
#   'vector': {'x1': 20721, 'x2': 20771, 'y1': 13008, 'y2': 13058},
#   'verified_by_user': 'False'},
#  {'annotation_type': 13,
#   'annotationversion_set': [],
#   'blurred': 'False',
#   'concealed': 'False',
#   'deleted': False,
#   'description': '',
#   'id': 404667,
#   'image': 55,
#   'last_edit_time': datetime.datetime(2021, 8, 17, 1, 43, 52, 579928),
#   'last_editor': 1,
#   'meta_data': None,
#   'time': datetime.datetime(2021, 8, 17, 1, 43, 52, 579877),
#   'unique_identifier': 'dd99c84c-5295-411e-bfb8-d834be4664c2',
#   'uploaded_media_files': [],
#   'user': 1,
#   'vector': {'x1': 20729, 'x2': 20779, 'y1': 13136, 'y2': 13186},
#   'verified_by_user': 'False'},
#  {'annotation_type': 13,
#   'annotationversion_set': [],
#   'blurred': 'False',
#   'concealed': 'False',
#   'deleted': False,
#   'description': '',
#   'id': 404668,
#   'image': 55,
#   'last_edit_time': datetime.datetime(2021, 8, 17, 1, 43, 52, 710778),
#   'last_editor': 1,
#   'meta_data': None,
#   'time': datetime.datetime(2021, 8, 17, 1, 43, 52, 710724),
#   'unique_identifier': '94e40432-4a31-4539-ba06-8caa81ed823c',
#   'uploaded_media_files': [],
#   'user': 1,
#   'vector': {'x1': 20745, 'x2': 20795, 'y1': 12932, 'y2': 12982},
#   'verified_by_user': 'False'},
#  {'annotation_type': 13,
#   'annotationversion_set': [],
#   'blurred': 'False',
#   'concealed': 'False',
#   'deleted': False,
#   'description': '',
#   'id': 404669,
#   'image': 55,
#   'last_edit_time': datetime.datetime(2021, 8, 17, 1, 43, 52, 897748),
#   'last_editor': 1,
#   'meta_data': None,
#   'time': datetime.datetime(2021, 8, 17, 1, 43, 52, 897695),
#   'unique_identifier': 'a9cae9f0-2191-427e-8f8b-54bf9e361cb7',
#   'uploaded_media_files': [],
#   'user': 1,
#   'vector': {'x1': 20748, 'x2': 20798, 'y1': 13424, 'y2': 13474},
#   'verified_by_user': 'False'},
#  {'annotation_type': 13,
#   'annotationversion_set': [],
#   'blurred': 'False',
#   'concealed': 'False',
#   'deleted': False,
#   'description': '',
#   'id': 404670,
#   'image': 55,
#   'last_edit_time': datetime.datetime(2021, 8, 17, 1, 43, 53, 36908),
#   'last_editor': 1,
#   'meta_data': None,
#   'time': datetime.datetime(2021, 8, 17, 1, 43, 53, 36852),
#   'unique_identifier': '21f135e4-dd41-492c-ac7d-a9e4737237b5',
#   'uploaded_media_files': [],
#   'user': 1,
#   'vector': {'x1': 20759, 'x2': 20809, 'y1': 12972, 'y2': 13022},
#   'verified_by_user': 'False'},
#  {'annotation_type': 13,
#   'annotationversion_set': [],
#   'blurred': 'False',
#   'concealed': 'False',
#   'deleted': False,
#   'description': '',
#   'id': 404671,
#   'image': 55,
#   'last_edit_time': datetime.datetime(2021, 8, 17, 1, 43, 53, 172119),
#   'last_editor': 1,
#   'meta_data': None,
#   'time': datetime.datetime(2021, 8, 17, 1, 43, 53, 172036),
#   'unique_identifier': '2e2c578a-f4b5-402f-b893-7fad12c2cfe3',
#   'uploaded_media_files': [],
#   'user': 1,
#   'vector': {'x1': 20896, 'x2': 20946, 'y1': 13380, 'y2': 13430},
#   'verified_by_user': 'False'},
#  {'annotation_type': 16,
#   'annotationversion_set': [],
#   'blurred': 'False',
#   'concealed': 'False',
#   'deleted': False,
#   'description': '',
#   'id': 404672,
#   'image': 55,
#   'last_edit_time': datetime.datetime(2021, 8, 17, 1, 43, 53, 380824),
#   'last_editor': 1,
#   'meta_data': None,
#   'time': datetime.datetime(2021, 8, 17, 1, 43, 53, 380747),
#   'unique_identifier': '266db48b-60b0-4159-8696-d4d76920fdf0',
#   'uploaded_media_files': [],
#   'user': 1,
#   'vector': {'x1': 21135, 'x2': 21185, 'y1': 13089, 'y2': 13139},
#   'verified_by_user': 'False'},
#  {'annotation_type': 13,
#   'annotationversion_set': [],
#   'blurred': 'False',
#   'concealed': 'False',
#   'deleted': False,
#   'description': '',
#   'id': 404673,
#   'image': 55,
#   'last_edit_time': datetime.datetime(2021, 8, 17, 1, 43, 53, 539196),
#   'last_editor': 1,
#   'meta_data': None,
#   'time': datetime.datetime(2021, 8, 17, 1, 43, 53, 539127),
#   'unique_identifier': '6dadc457-e8af-43e5-b4b4-084e0940226a',
#   'uploaded_media_files': [],
#   'user': 1,
#   'vector': {'x1': 21155, 'x2': 21205, 'y1': 12922, 'y2': 12972},
#   'verified_by_user': 'False'},
#  {'annotation_type': 13,
#   'annotationversion_set': [],
#   'blurred': 'False',
#   'concealed': 'False',
#   'deleted': False,
#   'description': '',
#   'id': 404674,
#   'image': 55,
#   'last_edit_time': datetime.datetime(2021, 8, 17, 1, 43, 53, 732615),
#   'last_editor': 1,
#   'meta_data': None,
#   'time': datetime.datetime(2021, 8, 17, 1, 43, 53, 732558),
#   'unique_identifier': '55049470-05bd-4722-8190-20fbc853068b',
#   'uploaded_media_files': [],
#   'user': 1,
#   'vector': {'x1': 21201, 'x2': 21251, 'y1': 12949, 'y2': 12999},
#   'verified_by_user': 'False'},
#  {'annotation_type': 13,
#   'annotationversion_set': [],
#   'blurred': 'False',
#   'concealed': 'False',
#   'deleted': False,
#   'description': '',
#   'id': 404675,
#   'image': 55,
#   'last_edit_time': datetime.datetime(2021, 8, 17, 1, 43, 53, 922216),
#   'last_editor': 1,
#   'meta_data': None,
#   'time': datetime.datetime(2021, 8, 17, 1, 43, 53, 922163),
#   'unique_identifier': 'fd853b4f-2e36-41a7-8471-0e0f5299af7a',
#   'uploaded_media_files': [],
#   'user': 1,
#   'vector': {'x1': 21318, 'x2': 21368, 'y1': 12994, 'y2': 13044},
#   'verified_by_user': 'False'},
#  {'annotation_type': 13,
#   'annotationversion_set': [],
#   'blurred': 'False',
#   'concealed': 'False',
#   'deleted': False,
#   'description': '',
#   'id': 404676,
#   'image': 55,
#   'last_edit_time': datetime.datetime(2021, 8, 17, 1, 43, 54, 101674),
#   'last_editor': 1,
#   'meta_data': None,
#   'time': datetime.datetime(2021, 8, 17, 1, 43, 54, 101586),
#   'unique_identifier': 'b9e035e5-5ffb-4a28-82d8-358e12f6396b',
#   'uploaded_media_files': [],
#   'user': 1,
#   'vector': {'x1': 20674, 'x2': 20724, 'y1': 12914, 'y2': 12964},
#   'verified_by_user': 'False'},
#  {'annotation_type': 13,
#   'annotationversion_set': [],
#   'blurred': 'False',
#   'concealed': 'False',
#   'deleted': False,
#   'description': '',
#   'id': 404677,
#   'image': 55,
#   'last_edit_time': datetime.datetime(2021, 8, 17, 1, 43, 54, 280291),
#   'last_editor': 1,
#   'meta_data': None,
#   'time': datetime.datetime(2021, 8, 17, 1, 43, 54, 280220),
#   'unique_identifier': '5ec02c46-1e46-4f19-9410-25f454f0d092',
#   'uploaded_media_files': [],
#   'user': 1,
#   'vector': {'x1': 20677, 'x2': 20727, 'y1': 13026, 'y2': 13076},
#   'verified_by_user': 'False'},
#  {'annotation_type': 13,
#   'annotationversion_set': [],
#   'blurred': 'False',
#   'concealed': 'False',
#   'deleted': False,
#   'description': '',
#   'id': 404678,
#   'image': 55,
#   'last_edit_time': datetime.datetime(2021, 8, 17, 1, 43, 54, 510718),
#   'last_editor': 1,
#   'meta_data': None,
#   'time': datetime.datetime(2021, 8, 17, 1, 43, 54, 510645),
#   'unique_identifier': '7d921b03-d05c-44eb-aaf6-5cce6efa3cbe',
#   'uploaded_media_files': [],
#   'user': 1,
#   'vector': {'x1': 20688, 'x2': 20738, 'y1': 13049, 'y2': 13099},
#   'verified_by_user': 'False'},
#  {'annotation_type': 13,
#   'annotationversion_set': [],
#   'blurred': 'False',
#   'concealed': 'False',
#   'deleted': False,
#   'description': '',
#   'id': 404679,
#   'image': 55,
#   'last_edit_time': datetime.datetime(2021, 8, 17, 1, 43, 54, 670100),
#   'last_editor': 1,
#   'meta_data': None,
#   'time': datetime.datetime(2021, 8, 17, 1, 43, 54, 670034),
#   'unique_identifier': '6061f46c-1c34-4f16-b6f1-2789da6a64fb',
#   'uploaded_media_files': [],
#   'user': 1,
#   'vector': {'x1': 21712, 'x2': 21762, 'y1': 13955, 'y2': 14005},
#   'verified_by_user': 'False'},
#  {'annotation_type': 13,
#   'annotationversion_set': [],
#   'blurred': 'False',
#   'concealed': 'False',
#   'deleted': False,
#   'description': '',
#   'id': 404680,
#   'image': 55,
#   'last_edit_time': datetime.datetime(2021, 8, 17, 1, 43, 54, 850541),
#   'last_editor': 1,
#   'meta_data': None,
#   'time': datetime.datetime(2021, 8, 17, 1, 43, 54, 850489),
#   'unique_identifier': '2049d930-0d56-4a32-bec7-735b76d300b1',
#   'uploaded_media_files': [],
#   'user': 1,
#   'vector': {'x1': 20753, 'x2': 20803, 'y1': 13806, 'y2': 13856},
#   'verified_by_user': 'False'},
#  {'annotation_type': 13,
#   'annotationversion_set': [],
#   'blurred': 'False',
#   'concealed': 'False',
#   'deleted': False,
#   'description': '',
#   'id': 404681,
#   'image': 55,
#   'last_edit_time': datetime.datetime(2021, 8, 17, 1, 43, 55, 26846),
#   'last_editor': 1,
#   'meta_data': None,
#   'time': datetime.datetime(2021, 8, 17, 1, 43, 55, 26719),
#   'unique_identifier': '12091d3e-c709-4c1c-b1c8-0ac794475fce',
#   'uploaded_media_files': [],
#   'user': 1,
#   'vector': {'x1': 20788, 'x2': 20838, 'y1': 13794, 'y2': 13844},
#   'verified_by_user': 'False'},
#  {'annotation_type': 13,
#   'annotationversion_set': [],
#   'blurred': 'False',
#   'concealed': 'False',
#   'deleted': False,
#   'description': '',
#   'id': 404682,
#   'image': 55,
#   'last_edit_time': datetime.datetime(2021, 8, 17, 1, 43, 55, 159372),
#   'last_editor': 1,
#   'meta_data': None,
#   'time': datetime.datetime(2021, 8, 17, 1, 43, 55, 159320),
#   'unique_identifier': '8df0d79e-4722-459f-8091-8553c11be710',
#   'uploaded_media_files': [],
#   'user': 1,
#   'vector': {'x1': 20906, 'x2': 20956, 'y1': 13841, 'y2': 13891},
#   'verified_by_user': 'False'},
#  {'annotation_type': 13,
#   'annotationversion_set': [],
#   'blurred': 'False',
#   'concealed': 'False',
#   'deleted': False,
#   'description': '',
#   'id': 404683,
#   'image': 55,
#   'last_edit_time': datetime.datetime(2021, 8, 17, 1, 43, 55, 298707),
#   'last_editor': 1,
#   'meta_data': None,
#   'time': datetime.datetime(2021, 8, 17, 1, 43, 55, 298626),
#   'unique_identifier': 'fa9453af-e78c-4a60-89b4-df8b5ec4e6ff',
#   'uploaded_media_files': [],
#   'user': 1,
#   'vector': {'x1': 20959, 'x2': 21009, 'y1': 14099, 'y2': 14149},
#   'verified_by_user': 'False'},
#  {'annotation_type': 13,
#   'annotationversion_set': [],
#   'blurred': 'False',
#   'concealed': 'False',
#   'deleted': False,
#   'description': '',
#   'id': 404684,
#   'image': 55,
#   'last_edit_time': datetime.datetime(2021, 8, 17, 1, 43, 55, 484677),
#   'last_editor': 1,
#   'meta_data': None,
#   'time': datetime.datetime(2021, 8, 17, 1, 43, 55, 484627),
#   'unique_identifier': '37cd5fee-d525-40e1-a280-269bc1906da1',
#   'uploaded_media_files': [],
#   'user': 1,
#   'vector': {'x1': 21080, 'x2': 21130, 'y1': 13540, 'y2': 13590},
#   'verified_by_user': 'False'},
#  {'annotation_type': 16,
#   'annotationversion_set': [],
#   'blurred': 'False',
#   'concealed': 'False',
#   'deleted': False,
#   'description': '',
#   'id': 404685,
#   'image': 55,
#   'last_edit_time': datetime.datetime(2021, 8, 17, 1, 43, 55, 620691),
#   'last_editor': 1,
#   'meta_data': None,
#   'time': datetime.datetime(2021, 8, 17, 1, 43, 55, 620633),
#   'unique_identifier': '9449ce23-0c49-4fff-999b-4b9dda63c46f',
#   'uploaded_media_files': [],
#   'user': 1,
#   'vector': {'x1': 21157, 'x2': 21207, 'y1': 13967, 'y2': 14017},
#   'verified_by_user': 'False'},
#  {'annotation_type': 13,
#   'annotationversion_set': [],
#   'blurred': 'False',
#   'concealed': 'False',
#   'deleted': False,
#   'description': '',
#   'id': 404686,
#   'image': 55,
#   'last_edit_time': datetime.datetime(2021, 8, 17, 1, 43, 55, 780495),
#   'last_editor': 1,
#   'meta_data': None,
#   'time': datetime.datetime(2021, 8, 17, 1, 43, 55, 780441),
#   'unique_identifier': '0688bd9d-7b63-40ee-af6d-d8b75a53521d',
#   'uploaded_media_files': [],
#   'user': 1,
#   'vector': {'x1': 21169, 'x2': 21219, 'y1': 14092, 'y2': 14142},
#   'verified_by_user': 'False'},
#  {'annotation_type': 16,
#   'annotationversion_set': [],
#   'blurred': 'False',
#   'concealed': 'False',
#   'deleted': False,
#   'description': '',
#   'id': 404687,
#   'image': 55,
#   'last_edit_time': datetime.datetime(2021, 8, 17, 1, 43, 55, 998207),
#   'last_editor': 1,
#   'meta_data': None,
#   'time': datetime.datetime(2021, 8, 17, 1, 43, 55, 998153),
#   'unique_identifier': '9cf79ad5-e5ae-4f61-bbbb-a403dca9364c',
#   'uploaded_media_files': [],
#   'user': 1,
#   'vector': {'x1': 21727, 'x2': 21777, 'y1': 14613, 'y2': 14663},
#   'verified_by_user': 'False'},
#  {'annotation_type': 13,
#   'annotationversion_set': [],
#   'blurred': 'False',
#   'concealed': 'False',
#   'deleted': False,
#   'description': '',
#   'id': 404688,
#   'image': 55,
#   'last_edit_time': datetime.datetime(2021, 8, 17, 1, 43, 56, 133248),
#   'last_editor': 1,
#   'meta_data': None,
#   'time': datetime.datetime(2021, 8, 17, 1, 43, 56, 133196),
#   'unique_identifier': 'd5bc6ce6-337c-487f-83a5-3a95250633a0',
#   'uploaded_media_files': [],
#   'user': 1,
#   'vector': {'x1': 20839, 'x2': 20889, 'y1': 14275, 'y2': 14325},
#   'verified_by_user': 'False'},
#  {'annotation_type': 13,
#   'annotationversion_set': [],
#   'blurred': 'False',
#   'concealed': 'False',
#   'deleted': False,
#   'description': '',
#   'id': 404689,
#   'image': 55,
#   'last_edit_time': datetime.datetime(2021, 8, 17, 1, 43, 56, 268509),
#   'last_editor': 1,
#   'meta_data': None,
#   'time': datetime.datetime(2021, 8, 17, 1, 43, 56, 268451),
#   'unique_identifier': '4164d6fc-ec7b-4fdb-b0db-2e08adb2d44d',
#   'uploaded_media_files': [],
#   'user': 1,
#   'vector': {'x1': 20909, 'x2': 20959, 'y1': 14224, 'y2': 14274},
#   'verified_by_user': 'False'},
#  {'annotation_type': 13,
#   'annotationversion_set': [],
#   'blurred': 'False',
#   'concealed': 'False',
#   'deleted': False,
#   'description': '',
#   'id': 404690,
#   'image': 55,
#   'last_edit_time': datetime.datetime(2021, 8, 17, 1, 43, 56, 449278),
#   'last_editor': 1,
#   'meta_data': None,
#   'time': datetime.datetime(2021, 8, 17, 1, 43, 56, 449226),
#   'unique_identifier': '7985653d-3698-4a5c-a11e-4ee4dd31601b',
#   'uploaded_media_files': [],
#   'user': 1,
#   'vector': {'x1': 20636, 'x2': 20686, 'y1': 14234, 'y2': 14284},
#   'verified_by_user': 'False'},
#  {'annotation_type': 13,
#   'annotationversion_set': [],
#   'blurred': 'False',
#   'concealed': 'False',
#   'deleted': False,
#   'description': '',
#   'id': 404691,
#   'image': 55,
#   'last_edit_time': datetime.datetime(2021, 8, 17, 1, 43, 56, 600938),
#   'last_editor': 1,
#   'meta_data': None,
#   'time': datetime.datetime(2021, 8, 17, 1, 43, 56, 600880),
#   'unique_identifier': '830d7798-b50f-48c2-a675-2bf1c0344327',
#   'uploaded_media_files': [],
#   'user': 1,
#   'vector': {'x1': 21002, 'x2': 21052, 'y1': 14404, 'y2': 14454},
#   'verified_by_user': 'False'},
#  {'annotation_type': 13,
#   'annotationversion_set': [],
#   'blurred': 'False',
#   'concealed': 'False',
#   'deleted': False,
#   'description': '',
#   'id': 404692,
#   'image': 55,
#   'last_edit_time': datetime.datetime(2021, 8, 17, 1, 43, 56, 750920),
#   'last_editor': 1,
#   'meta_data': None,
#   'time': datetime.datetime(2021, 8, 17, 1, 43, 56, 750840),
#   'unique_identifier': '7835d2f4-c8ae-4e3c-af39-dc3cc1e9aff1',
#   'uploaded_media_files': [],
#   'user': 1,
#   'vector': {'x1': 21061, 'x2': 21111, 'y1': 14248, 'y2': 14298},
#   'verified_by_user': 'False'}]

# %%
#delete annotations
for anno in annotation_results:
    annotations_api.destroy_annotation(id=anno.id)
    print(anno.id)
# Out:
# 404640
# 404641
# 404642

# %%
while (len(threads) > 0):
    for thread in threads:
        if thread.ready():
            data.results += thread.get().results
            threads.remove(thread)
    sleep(0.25)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-119-167da536c902> in <module>
#       1 while (len(threads) > 0):
#       2     for thread in threads:
# ----> 3         if thread.ready():
#       4             threads.remove(thread)
#
# AttributeError: 'Annotation' object has no attribute 'ready'
